# %%
import pandas as pd
import numpy as np

# %%
url="https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/breast-cancer.csv"
df = pd.read_csv(url)
df.sample(4)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 179  873586         B        12.81         13.06           81.29      508.8
# 561  925311         B        11.20         29.37           70.67      386.0
# 38   855133         M        14.99         25.20           95.54      698.8
# 497  914580         B        12.47         17.31           80.45      480.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 179          0.08739           0.03774        0.009193              0.01330
# 561          0.07449           0.03558        0.000000              0.00000
# 38           0.09387           0.05131        0.023980              0.02899
# 497          0.08928           0.07630        0.036090              0.02369
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 179  ...         13.63          16.15            86.70       570.7
# 561  ...         11.92          38.30            75.19       439.6
# 38   ...         14.99          25.20            95.54       698.8
# 497  ...         14.06          24.34            92.82       607.3
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 179           0.11620            0.05445          0.02758
# 561           0.09267            0.05494          0.00000
# 38            0.09387            0.05131          0.02398
# 497           0.12760            0.25060          0.20280
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 179               0.03990          0.1783                  0.07319
# 561               0.00000          0.1566                  0.05905
# 38                0.02899          0.1565                  0.05504
# 497               0.10530          0.3035                  0.07661
#
# [4 rows x 32 columns]

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df['diagnosis']=labelencoder.fit_transform(df['diagnosis'].values)
df['diagnosis']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int32

# %%
corrm=df.corr().abs()
corrm.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c645f_row0_col0, #T_c645f_row1_col1, #T_c645f_row2_col2, #T_c645f_row2_col4, #T_c645f_row3_col3, #T_c645f_row4_col2, #T_c645f_row4_col4, #T_c645f_row5_col5, #T_c645f_row6_col6, #T_c645f_row7_col7, #T_c645f_row8_col8, #T_c645f_row9_col9, #T_c645f_row10_col10, #T_c645f_row11_col11, #T_c645f_row12_col12, #T_c645f_row13_col13, #T_c645f_row14_col14, #T_c645f_row15_col15, #T_c645f_row16_col16, #T_c645f_row17_col17, #T_c645f_row18_col18, #T_c645f_row19_col19, #T_c645f_row20_col20, #T_c645f_row21_col21, #T_c645f_row22_col22, #T_c645f_row23_col23, #T_c645f_row24_col24, #T_c645f_row25_col25, #T_c645f_row26_col26, #T_c645f_row27_col27, #T_c645f_row28_col28, #T_c645f_row29_col29, #T_c645f_row30_col30, #T_c645f_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c645f_row0_col1, #T_c645f_row6_col23, #T_c645f_row15_col30, #T_c645f_row17_col0, #T_c645f_row29_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c645f_row0_col2, #T_c645f_row0_col4, #T_c645f_row3_col26, #T_c645f_row5_col20, #T_c645f_row8_col13, #T_c645f_row11_col3, #T_c645f_row14_col30, #T_c645f_row15_col16, #T_c645f_row20_col5, #T_c645f_row21_col30, #T_c645f_row23_col10, #T_c645f_row23_col16, #T_c645f_row26_col13, #T_c645f_row30_col19 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c645f_row0_col3, #T_c645f_row5_col0, #T_c645f_row13_col15, #T_c645f_row16_col0, #T_c645f_row18_col23, #T_c645f_row20_col22, #T_c645f_row24_col13, #T_c645f_row26_col14, #T_c645f_row29_col16, #T_c645f_row30_col12, #T_c645f_row31_col16 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_c645f_row0_col5, #T_c645f_row0_col16, #T_c645f_row2_col13, #T_c645f_row3_col18, #T_c645f_row3_col19, #T_c645f_row8_col16, #T_c645f_row13_col2, #T_c645f_row13_col29, #T_c645f_row15_col11, #T_c645f_row22_col31 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c645f_row0_col6, #T_c645f_row0_col7, #T_c645f_row0_col8, #T_c645f_row0_col10, #T_c645f_row0_col13, #T_c645f_row0_col17, #T_c645f_row0_col18, #T_c645f_row0_col19, #T_c645f_row0_col26, #T_c645f_row0_col27, #T_c645f_row0_col28, #T_c645f_row0_col30, #T_c645f_row1_col13, #T_c645f_row1_col20, #T_c645f_row2_col31, #T_c645f_row3_col16,
{
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c645f_row1_col9, #T_c645f_row29_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_c645f_row1_col10, #T_c645f_row16_col17, #T_c645f_row27_col14 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_c645f_row1_col11, #T_c645f_row6_col0, #T_c645f_row9_col13, #T_c645f_row15_col31, #T_c645f_row20_col28 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c645f_row1_col12, #T_c645f_row26_col27, #T_c645f_row29_col19 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c645f_row1_col14, #T_c645f_row19_col14, #T_c645f_row19_col28, #T_c645f_row22_col7, #T_c645f_row29_col14, #T_c645f_row30_col31 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c645f_row1_col15, #T_c645f_row14_col29, #T_c645f_row29_col26 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_c645f_row1_col17, #T_c645f_row3_col8, #T_c645f_row6_col14, #T_c645f_row20_col18, #T_c645f_row30_col24 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c645f_row1_col18, #T_c645f_row10_col15, #T_c645f_row12_col13, #T_c645f_row17_col5, #T_c645f_row19_col26, #T_c645f_row22_col26, #T_c645f_row22_col30 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c645f_row1_col19, #T_c645f_row3_col24, #T_c645f_row4_col19, #T_c645f_row17_col12, #T_c645f_row22_col23, #T_c645f_row23_col27, #T_c645f_row27_col23, #T_c645f_row29_col23 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_c645f_row1_col21, #T_c645f_row2_col0, #T_c645f_row3_col11, #T_c645f_row4_col20, #T_c645f_row13_col22, #T_c645f_row20_col4, #T_c645f_row20_col9, #T_c645f_row20_col23, #T_c645f_row20_col31, #T_c645f_row25_col13, #T_c645f_row25_col31 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c645f_row1_col22, #T_c645f_row11_col31, #T_c645f_row31_col11 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_c645f_row1_col23, #T_c645f_row4_col27, #T_c645f_row15_col7, #T_c645f_row23_col1,

# %%
df.corrwith(df['diagnosis']).abs().sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# smoothness_se              0.067016
# id                         0.039769
# fractal_dimension_mean     0.012838
# texture_se                 0.008303
# symmetry_se                0.006522
# dtype: float64

# %%
cols=['concave points_worst','perimeter_worst','concave points_mean','radius_worst','perimeter_mean','area_worst','radius_mean','area_mean','concavity_mean','concavity_worst','compactness_mean','compactness_worst']
X=df[cols].copy()
y=df['diagnosis'].copy()

# %%
from sklearn.preprocessing import StandardScaler
sscaler=StandardScaler()
X=sscaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train,y_train)
y_predict=knn.predict(X_test)

# %%
from sklearn.metrics import jaccard_score
jaccard_score(y_test,y_predict)
# Out:
# 0.7894736842105263

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)
# Out:
# array([[38,  3],
#        [ 1, 15]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        41
#            1       0.83      0.94      0.88        16
#
#     accuracy                           0.93        57
#    macro avg       0.90      0.93      0.92        57
# weighted avg       0.93      0.93      0.93        57

# %%
from sklearn.model_selection import cross_val_predict
prediction=cross_val_predict(estimator=knn,X=X,y=y,cv=9)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        41
#            1       0.83      0.94      0.88        16
#
#     accuracy                           0.93        57
#    macro avg       0.90      0.93      0.92        57
# weighted avg       0.93      0.93      0.93        57
